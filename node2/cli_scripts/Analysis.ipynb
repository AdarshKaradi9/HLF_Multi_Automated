# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import plotly.express as px

# %%
# !ls
# Out:
# analysis_invoke.sh	  backup_log.txt     invoke.csv  script1.sh
# Analysis.ipynb		  backup_script.sh   log.txt	 script.sh
# analysis_query.sh	  backup_utils.sh    query.csv	 tit.json
# backup_capabilities.json  capabilities.json  query.sh	 utils.sh

# %%
query = pd.read_csv('query.csv')

# %%
query
# Out:
#     Number_of_Transaction     Time(s)
# 0                       1    3.113405
# 1                       2    6.191574
# 2                       4   12.369794
# 3                       6   18.584733
# 4                       8   24.767705
# 5                      10   31.079062
# 6                      14   43.393666
# 7                      18   55.879899
# 8                      22   68.551118
# 9                      26   80.596279
# 10                     32   99.260436
# 11                     42  130.215582
# 12                     52  161.483085

# %%
invoke = pd.read_csv('invoke.csv')

# %%
invoke
# Out:
#     Number_of_Transaction   Time(s)
# 0                       1  0.084270
# 1                       2  0.205772
# 2                       4  0.404929
# 3                       6  0.621420
# 4                       8  0.803086
# 5                      10  1.114969
# 6                      14  1.502883
# 7                      18  1.902387
# 8                      22  3.140661
# 9                      26  2.985944
# 10                     32  3.371219
# 11                     42  4.802631
# 12                     52  6.681888

# %%
fig1 = px.line(query,x="Number_of_Transaction",y="Time(s)",title='Number of query transactions vs. Time(s)')
fig1.show()

# %%
fig2 = px.line(invoke,x="Number_of_Transaction",y="Time(s)",title='Number of Invoke transactions vs. Time(s)')
fig2.show()
